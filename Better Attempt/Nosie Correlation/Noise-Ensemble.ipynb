# %%
import numpy as np
from qiskit import QuantumCircuit, transpile
from qiskit.quantum_info import Statevector
from scipy.stats import unitary_group
from itertools import combinations
import matplotlib.pyplot as plt
import scienceplots
from scipy.optimize import minimize
from IPython.display import clear_output
from numpy import einsum as contract


plt.style.use(['science','ieee', 'no-latex'])

# %%
n = 2
na = 2
n_tot = n + na
T = 20
L = 6
Ndata = 100
Nparams = 2 * L * n_tot

# %% [markdown]
# ### Diffusion Model

# %%
from numpy import einsum as contract

def corrNoiseEnsemble(psi0, delta, p, Ndata, seed):

    np.random.seed(seed)

    # Define the Pauli matrices and their tensor products
    X = np.array([[0, 1], [1, 0]])
    Z = np.array([[1, 0], [0, -1]])
    XX = contract('ij,kl->ikjl', X, X).reshape((4, 4))
    ZZ = contract('ij,kl->ikjl', Z, Z).reshape((4, 4))

    # Determine noise types (1 for XX, 2 for ZZ) based on probabilities
    noise_types = np.random.choice([1, 2], size=Ndata, replace=True, p=[p, 1-p])

    # Random angles uniformly sampled from [-delta, delta]
    angles = np.random.uniform(-delta, delta, Ndata)

    # Construct noise unitaries for each sample
    Us = []
    for i, angle in enumerate(angles):
        if noise_types[i] == 1:  # XX gate
            U = np.cos(angle) * np.eye(4) - 1j * np.sin(angle) * XX
        else:  # ZZ gate
            U = np.cos(angle) * np.eye(4) - 1j * np.sin(angle) * ZZ
        Us.append(U)

    Us = np.array(Us)  # Shape (Ndata, 4, 4)

    # Apply noise unitaries to the initial state psi0
    states = np.array([U @ psi0 for U in Us])  # Shape (Ndata, 4)

    return states

# %%
def haarSample(Ndata, seed):
    np.random.seed(seed)
    states_T = [unitary_group.rvs(2**n)[:, 0] for _ in range(Ndata)]
    return states_T

# %%
def diffusionCircuit(t, input_state, phis, gs=None):
    qc = QuantumCircuit(n)

    state = Statevector(input_state)

    # Apply the parameterized gates
    for tt in range(t):
        for i in range(n):
            qc.rz(phis[3 * n * tt + i], i)
            qc.ry(phis[3 * n * tt + n + i], i)
            qc.rz(phis[3 * n * tt + 2 * n + i], i)
        if n >= 2 and gs is not None:
            for i, j in combinations(range(n), 2):
                qc.rzz(gs[tt] / (2 * np.sqrt(n)), i, j)
    
    state = state.evolve(qc)
    return state

# %%
def diffusionData(t, inputs, diff_hs, seed):

    np.random.seed(seed) 

    phis = (np.random.rand(Ndata, 3 * n * t) * np.pi / 4 - np.pi / 8) * diff_hs.repeat(3 * n)
    if n > 1:
        gs = (np.random.rand(Ndata, t) * 0.2 + 0.4) * diff_hs
    else:
        gs = None

    states = np.zeros((Ndata, 2**n), dtype=np.complex128)

    for i in range(Ndata):
        states[i] = diffusionCircuit(t, inputs[i], phis[i], gs[i] if gs is not None else None).data

    return states

# %%
delta = np.pi/3
p = 0.8
diff_hs = np.hstack((np.linspace(0.05, 1., 12), np.linspace(1.2, 4., 8))).astype(np.float32)

psi0 = np.array([np.sqrt(0.1)*np.exp(1j*0.8), np.sqrt(0.55)*np.exp(1j*1.7), 
                    0., np.sqrt(0.35)*np.exp(1j*2.4)])

X = corrNoiseEnsemble(psi0,delta,p,Ndata,seed=12)

S = np.zeros((T + 1, Ndata, 2**n), dtype=np.complex64)
S[0] = X

for t in range(1, T + 1):
    S[t] = diffusionData(t, X, diff_hs[:t], seed=t)

# %%
plt.plot(range(T+1), np.mean(np.abs(S[:,:,2])**2, axis=1), 'o-', c='r', markersize=3)
plt.fill_between(range(T+1), np.mean(np.abs(S[:,:,2])**2, axis=1) - np.std(np.abs(S[:,:,2])**2, axis=1),
                 np.mean(np.abs(S[:,:,2])**2, axis=1) + np.std(np.abs(S[:,:,2])**2, axis=1), 
                 color='r', alpha=0.25)
plt.plot(range(T+1), np.ones(T+1)*0.25, '--')
plt.ylabel(r'$\bar{F}_{10}$')
plt.xlabel(r'Diffusion Step $t$')
# Out:
# Text(0.5, 0, 'Diffusion Step $t$')

# %% [markdown]
# ### Denoising Model

# %%
def randomMeasure(input_state):
    reshaped = input_state.reshape(2**na, 2**n)
    m_probs = np.sum(np.abs(reshaped)**2, axis=1)  # probabilities of ancilla states
    m_probs = m_probs / np.sum(m_probs)

    m_res = np.random.choice(len(m_probs), p=m_probs)  # Measure and select an ancilla state
    indices = 2**n * m_res + np.arange(2**n)  # Index of post-measurement state

    post_state = input_state[indices]  # Select the corresponding post-measurement state

    norm = np.linalg.norm(post_state)
    if norm == 0:
        norm = 1 

    normalized_state = post_state / norm
    return normalized_state

# %%
def denoisingLayer(input_state, params, n_tot, L):
  
    state = Statevector(input_state)

    qc = QuantumCircuit(n_tot)

    # Apply layers of gates
    for l in range(L):
        for i in range(n_tot):
            qc.rx(params[2 * n_tot * l + i], i)
            qc.ry(params[2 * n_tot * l + n_tot + i], i)
        for i in range(n_tot // 2):
            qc.cz(2 * i, 2 * i + 1)
        if n_tot % 2 == 1: 
            qc.cz(n_tot - 2, n_tot - 1)

    state = state.evolve(qc)

    return randomMeasure(state.data)

# %%
ancilla = np.zeros(2**na)
ancilla[0] = 1

# %%
def denoisingFull(input_state, params, n_tot, L, t):
    x = []
    x.append(input_state) 
    for t in range(T,t-1,-1):
        p = params[(T-t) * Nparams : (T-t+1) * Nparams]
        outcome = denoisingLayer(x[-1], p, n_tot, L)
        x.append(np.kron(outcome[outcome!=0], ancilla))
    return x[-1]

# %%
ApproxS = [None] * (T+1)
ApproxS[-1] = haarSample(Ndata,seed=22)

# %%
def maxMeanDiscripency(set1, set2):
    set1 = np.array(set1, dtype=np.complex128)
    set2 = np.array(set2, dtype=np.complex128)
    
    r11 = np.mean(np.abs(set1 @ set1.conj().T)**2)
    r22 = np.mean(np.abs(set2 @ set2.conj().T)**2)
    r12 = np.mean(np.abs(set1 @ set2.conj().T)**2)
    return r11 + r22 - 2 * r12

# %%
loss_hist = []

theta = np.random.uniform(0,2*np.pi, T * Nparams)

def costFunction(params, t):
    output = []
    ApproxS[t-1] = []
    for i in range(Ndata):
        input = np.kron(ApproxS[t][i], ancilla)
        #input = input / np.linalg.norm(input)
        #temp = denoisingFull(input, np.array(theta[0: (T-t+1) * Nparams]), n_tot, L, t+1)
        #output.append(denoisingLayer(temp, np.array(params), n_tot, L))
        #output[i] = output[i] / np.linalg.norm(output[i])
        output = denoisingLayer(input, np.array(params), n_tot, L)
        ApproxS[t-1].append(output[output!=0])

    cost = maxMeanDiscripency(ApproxS[t-1], S[t-1])
    loss_hist.append(cost)

    # Clear output and update the real-time plot
    clear_output(wait=True)
    plt.xlabel("Training Step")
    plt.yscale("log")
    plt.ylabel(r"$\mathcal{D}_{\text{MMD}} (\tilde{\mathcal{S}}_t, \mathcal{S}_t)$")
    plt.plot(range(len(loss_hist)), loss_hist)
    plt.title(f"Current Step: {t}")
    plt.show()

    return cost

# %%
for k in np.arange(T,0,-1):
    result = minimize(
        costFunction,
        theta[(T-k) * Nparams : (T-k+1) * Nparams],
        args=(k,),
        method="COBYLA",
        options={"maxiter": 500, 'tol':1e-10},
    )

    theta[ (T-k) * Nparams : (T-k+1) * Nparams] = result.x

# %%
plt.xlabel("Training Step")
#plt.yscale('log')
plt.ylabel(r'$\mathcal{D}_{\text{MMD}} (\tilde{\mathcal{S}}_t, \mathcal{S}_t)$')
plt.plot(range(len(loss_hist)), loss_hist)

secax = plt.gca().secondary_xaxis('top')
secax.set_xlabel(fr"Diffusion Step $t$")
secax.set_xticklabels(np.arange(T+4,-1,-4))
plt.savefig('Noise-Loss.pdf', bbox_inches='tight')
# Out:
# /var/folders/z8/g5m0xfqn4nx8cgfn199lgfq40000gn/T/ipykernel_2092/3583303011.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   secax.set_xticklabels(np.arange(T+5,-1,-5))

# %% [markdown]
# ### Testing and Visualisation

# %%
testS = [None] * (T+1)

testS[T] = haarSample(Ndata, seed=24)

for t in range(T,0,-1):
    testS[t-1] = []
    for i in range(Ndata):
        input = np.kron(testS[T][i], ancilla)
        input = input / np.linalg.norm(input)
        temp = denoisingFull(input, np.array(theta[0: (T-t+1) * Nparams]), n_tot, L, t)
        testS[t-1].append(temp[temp!=0])

# %%
mmds = np.zeros((3, T+1))
for t in range(T+1):
    idx = np.random.choice(S.shape[1], size=Ndata, replace=False)
    mmds[0, t] = maxMeanDiscripency(S[0], S[t, idx])
    mmds[1, t] = maxMeanDiscripency(S[0], ApproxS[t])
    mmds[2, t] = maxMeanDiscripency(S[0], testS[t])

fig, ax = plt.subplots()
ax.plot(mmds[0], 'o-', c='r', label=r'Diffusion', markersize=3)
ax.plot(mmds[1], 'o-', c='b', label=r'Training', markersize=3)
ax.plot(mmds[2], 'o-', c='g', label=r'Testing', markersize=3)

ax.legend(loc = 'best')
ax.set_xlabel(r'Diffusion Step $t$')
ax.set_ylabel(r'$\mathcal{D}_{\rm MMD}(\tilde{\mathcal{S}}_t, \mathcal{S}_0)$')
plt.savefig('Noise-DistanceInitial.pdf', bbox_inches='tight' )

# %%
a = np.array(S)
b = np.array(ApproxS)
c = np.array(testS)

# %%
f10_diff = np.abs(a[:, :, 2])**2
f10_train = np.abs(b[:, :, 2])**2
f10_test = np.abs(c[:, :, 2])**2

fig, ax = plt.subplots()
ax.plot(range(T+1), np.mean(f10_diff, axis=1), 'o-', markersize=3,  c='r', 
            label=r'Diffusion')
ax.plot(range(T+1), np.mean(f10_train, axis=1), 'o-', markersize=3, c='b', 
            label=r'Training')
ax.plot(range(T+1), np.mean(f10_test, axis=1), 'o-', markersize=3,   
            c='g',  label=r'Testing')
ax.set_ylabel(r'$\overline{F_{10}}$')
ax.set_xlabel(r'$t$')
ax.legend(loc='best')
plt.savefig('Noise-Fidelity.pdf')

# %%
denom = np.abs(np.sqrt(0.55)*np.exp(1j*1.7))**2 
denom = denom * 0.75

VALUES = np.mean(f10_train, axis=1) / denom

VALUES_Te = np.mean(f10_test, axis=1) / denom

plt.plot(range(T+1), [p] * (T+1), 'k--', label=r'True Value $p$')
plt.plot(range(T+1), VALUES, label='Training', c='b')
plt.plot(range(T+1), VALUES_Te, label='Testing', c='g')
plt.legend(loc='best')
plt.xlabel(r'Diffusion Step $t$')
plt.ylabel(r'$p$ value')
plt.savefig('Noise-Prediction.pdf')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 denom = np.abs(np.sqrt(0.55)*np.exp(1j*1.7))**2
#       2 denom = denom * 0.75
#       4 VALUES = np.mean(f10_train, axis=1) / denom
#
# NameError: name 'np' is not defined
